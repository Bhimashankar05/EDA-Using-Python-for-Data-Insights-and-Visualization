# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('military expenditure.csv')
df
# Out:
#            country iso3c iso2c  year  Military expenditure (current USD)  \
# 0      Afghanistan   AFG    AF  1970                        2.939586e+06
# 1      Afghanistan   AFG    AF  1971                                 NaN
# 2      Afghanistan   AFG    AF  1972                                 NaN
# 3      Afghanistan   AFG    AF  1973                        3.341272e+06
# 4      Afghanistan   AFG    AF  1974                        3.581366e+06
# ...            ...   ...   ...   ...                                 ...
# 13561     Zimbabwe   ZWE    ZW  2016                        3.580650e+08
# 13562     Zimbabwe   ZWE    ZW  2017                        3.405220e+08
# 13563     Zimbabwe   ZWE    ZW  2018                        4.203640e+08
# 13564     Zimbabwe   ZWE    ZW  2019                        5.469390e+08
# 13565     Zimbabwe   ZWE    ZW  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# ...

# %%
df.columns
# Out:
# Index(['country', 'iso3c', 'iso2c', 'year',
#        'Military expenditure (current USD)',
#        'Military expenditure (% of general government expenditure)',
#        'Military expenditure (% of GDP)', 'adminregion', 'incomeLevel'],
#       dtype='object')

# %%
df.country.unique()
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
# ...

# %%
df.country.nunique()
# Out:
# 266

# %%
df.head(2)
# Out:
#        country iso3c iso2c  year  Military expenditure (current USD)  \
# 0  Afghanistan   AFG    AF  1970                        2.939586e+06
# 1  Afghanistan   AFG    AF  1971                                 NaN
#
#    Military expenditure (% of general government expenditure)  \
# 0                                                NaN
# 1                                                NaN
#
#    Military expenditure (% of GDP) adminregion incomeLevel
# 0                         1.629606  South Asia  Low income
# 1                              NaN  South Asia  Low income

# %%
sns.barplot(x='incomeLevel',y='Military expenditure (% of GDP)',data=df)
plt.tight_layout()

#The countries with High Income Have Max Military Expenditure

# %%
sns.barplot(x='incomeLevel',y='Military expenditure (% of GDP)',data=df,hue='adminregion')
plt.tight_layout()

#Middle East & North Africa Expenditure is very high compared to other adminregion... 
#They need to look towards healthy Relationship with Neighbouring Countries

# %%
df.adminregion.nunique()
# Out:
# 6

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x='year',y='Military expenditure (% of GDP)',data=df)

# %%
sns.histplot(data=df,x='year',y='Military expenditure (% of GDP)')
# Out:
# <AxesSubplot:xlabel='year', ylabel='Military expenditure (% of GDP)'>

# %%
df.head()
# Out:
#        country iso3c iso2c  year  Military expenditure (current USD)  \
# 0  Afghanistan   AFG    AF  1970                        2.939586e+06
# 1  Afghanistan   AFG    AF  1971                                 NaN
# 2  Afghanistan   AFG    AF  1972                                 NaN
# 3  Afghanistan   AFG    AF  1973                        3.341272e+06
# 4  Afghanistan   AFG    AF  1974                        3.581366e+06
#
#    Military expenditure (% of general government expenditure)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Military expenditure (% of GDP) adminregion incomeLevel
# 0                         1.629606  South Asia  Low income
# 1                              NaN  South Asia  Low income
# ...

# %%
I=df.groupby('country').get_group('India')
I
# Out:
#      country iso3c iso2c  year  Military expenditure (current USD)  \
# 5661   India   IND    IN  1970                        1.832967e+09
# 5662   India   IND    IN  1971                        2.255257e+09
# 5663   India   IND    IN  1972                        2.497245e+09
# 5664   India   IND    IN  1973                        2.529921e+09
# 5665   India   IND    IN  1974                        2.895416e+09
# 5666   India   IND    IN  1975                        3.323647e+09
# 5667   India   IND    IN  1976                        3.294911e+09
# 5668   India   IND    IN  1977                        3.477081e+09
# 5669   India   IND    IN  1978                        3.975819e+09
# 5670   India   IND    IN  1979                        4.589738e+09
# 5671   India   IND    IN  1980                        5.420810e+09
# 5672   India   IND    IN  1981                        5.879007e+09
# 5673   India   IND    IN  1982                        6.302108e+09
# ...

# %%
sns.jointplot(x='year',y='Military expenditure (% of GDP)',data=I)

#Initially Indias' Military Expenditure was Almost double than 2020...It is in contol from 1990
