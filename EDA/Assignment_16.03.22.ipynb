# %%
import pandas as pd

# %%
df =pd.read_csv('D:\\DS Study\\Data scientist salary.csv')
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %% [markdown]
# # How many rows and coluns data have?

# %%
df.shape
# Out:
# (742, 20)

# %%
print('Total no of rows: ',df.shape[0],'\nTotal no of columns: ',df.shape[1])
# Out:
# Total no of rows:  742
# Total no of columns:  20

# %% [markdown]
# # Give short info about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Lower Salary       742 non-null    int64
#  14  Upper Salary       742 non-null    int64
#  15  Avg Salary(K)      742 non-null    float64
# ...

# %% [markdown]
# #  Show all columns name of data

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Lower Salary',
#        'Upper Salary', 'Avg Salary(K)', 'Job Location', 'Age', 'job_title_sim',
#        'Degree'],
#       dtype='object')

# %% [markdown]
# # Check for missing entries

# %%
df.isna().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Lower Salary         0
# Upper Salary         0
# Avg Salary(K)        0
# Job Location         0
# Age                  0
# job_title_sim        0
# Degree               0
# dtype: int64

# %% [markdown]
# * But in Revenue column unknown or not applicable entries are more so will check for reveue column

# %%
df.Revenue.value_counts()
# Out:
# Unknown / Non-Applicable            204
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# Name: Revenue, dtype: int64

# %% [markdown]
# * Same for degree column unknown na is there so check for degree column

# %%
df.Degree.value_counts()
# Out:
# na    383
# M     252
# P     107
# Name: Degree, dtype: int64

# %% [markdown]
# * so we skip Revenue and Degree column

# %%
df.drop(labels =['Revenue','Degree'],axis = 1,inplace=True)
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %% [markdown]
# # how many total post are available?

# %%
df['Job Title'].nunique()
# Out:
# 264

# %% [markdown]
# # which types posts are there?

# %%
df['Job Title'].unique()
# Out:
# array(['Data Scientist', 'Healthcare Data Scientist',
#        'Research Scientist', 'Staff Data Scientist - Technology',
#        'Data Analyst', 'Data Engineer I', 'Scientist I/II, Biology',
#        'Customer Data Scientist',
#        'Data Scientist - Health Data Analytics',
#        'Senior Data Scientist / Machine Learning',
#        'Data Scientist - Quantitative', 'Digital Health Data Scientist',
#        'Associate Data Analyst', 'Clinical Data Scientist',
#        'Data Scientist / Machine Learning Expert', 'Web Data Analyst',
#        'Senior Data Scientist', 'Data Engineer',
#        'Data Scientist - Algorithms & Inference', 'Scientist',
#        'Lead Data Scientist', 'Spectral Scientist/Engineer',
#        'College Hire - Data Scientist - Open to December 2019 Graduates',
#        'Data Scientist, Office of Data Science', 'Data Science Analyst',
#        'Senior Risk Data Scientist',
#        'Data Scientist in Artificial Intelligence Early Career',
# ...

# %% [markdown]
# #   job available for 'Data Scientist'

# %%
df.groupby('Job Title').get_group('Data Scientist')
# Out:
#           Job Title               Salary Estimate  \
# 0    Data Scientist    $53K-$91K (Glassdoor est.)
# 2    Data Scientist    $80K-$90K (Glassdoor est.)
# 3    Data Scientist    $56K-$97K (Glassdoor est.)
# 4    Data Scientist   $86K-$143K (Glassdoor est.)
# 5    Data Scientist   $71K-$119K (Glassdoor est.)
# ..              ...                           ...
# 684  Data Scientist   $77K-$132K (Glassdoor est.)
# 685  Data Scientist    $51K-$88K (Glassdoor est.)
# 686  Data Scientist  $101K-$141K (Glassdoor est.)
# 700  Data Scientist   $65K-$113K (Glassdoor est.)
# 714  Data Scientist   $96K-$161K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ...

# %% [markdown]
# # how many companies are availabe

# %%
df['Company Name'].nunique()
# Out:
# 343

# %% [markdown]
# # Make a group for salary estimte & show the group wise lower to higher salary estimation

# %%
a=df['Salary Estimate'].unique()
a.sort()
print(a)
# Out:
# ['$10-$17 Per Hour(Glassdoor est.)' '$100K-$160K (Glassdoor est.)'
#  '$100K-$166K (Glassdoor est.)' '$100K-$173K (Glassdoor est.)'
#  '$100K-$190K (Glassdoor est.)' '$101K-$141K (Glassdoor est.)'
#  '$101K-$158K (Glassdoor est.)' '$102K-$163K (Glassdoor est.)'
#  '$102K-$164K (Glassdoor est.)' '$102K-$165K (Glassdoor est.)'
#  '$102K-$172K (Glassdoor est.)' '$102K-$178K (Glassdoor est.)'
#  '$102K-$190K (Glassdoor est.)' '$105K-$173K (Glassdoor est.)'
#  '$105K-$194K (Glassdoor est.)' '$105K-$198K (Glassdoor est.)'
#  '$106K-$172K (Glassdoor est.)' '$107K-$172K (Glassdoor est.)'
#  '$107K-$173K (Glassdoor est.)' '$108K-$146K (Glassdoor est.)'
#  '$108K-$171K (Glassdoor est.)' '$108K-$173K (Glassdoor est.)'
#  '$108K-$176K (Glassdoor est.)' '$109K-$177K (Glassdoor est.)'
#  '$109K-$200K (Glassdoor est.)' '$110K-$150K(Employer est.)'
#  '$110K-$174K (Glassdoor est.)' '$110K-$175K (Glassdoor est.)'
#  '$110K-$184K (Glassdoor est.)' '$111K-$176K (Glassdoor est.)'
# ...

# %% [markdown]
# ## Group by per Hour

# %%
for i in a:
    if 'Per Hour' in i:
        b=print(i)
# Out:
# $10-$17 Per Hour(Glassdoor est.)
# $15-$25 Per Hour(Glassdoor est.)
# $17-$24 Per Hour(Glassdoor est.)
# $18-$25 Per Hour(Glassdoor est.)
# $21-$29 Per Hour(Glassdoor est.)
# $21-$34 Per Hour(Glassdoor est.)
# $24-$39 Per Hour(Glassdoor est.)
# $27-$47 Per Hour(Glassdoor est.)
# Employer Provided Salary:$25-$28 Per Hour

# %% [markdown]
# ## Groupby Employer

# %%
for i in a:
    if 'Employer' in i:
        print(i)
# Out:
# $110K-$150K(Employer est.)
# $15K-$16K(Employer est.)
# $190K-$220K(Employer est.)
# $200K-$275K(Employer est.)
# $80K-$105K(Employer est.)
# $82K-$129K(Employer est.)
# $90K-$110K(Employer est.)
# Employer Provided Salary:$100K-$135K
# Employer Provided Salary:$100K-$140K
# Employer Provided Salary:$110K-$130K
# Employer Provided Salary:$120K-$140K
# Employer Provided Salary:$120K-$145K
# Employer Provided Salary:$150K-$160K
# Employer Provided Salary:$200K-$250K
# Employer Provided Salary:$25-$28 Per Hour
# Employer Provided Salary:$85K-$90K

# %% [markdown]
# ## Groupby direct Glassdoor est.

# %%
for i in a:
    if 'Per Hour'not in i:
        if 'Employer'not in i:
            print(i)
# Out:
# $100K-$160K (Glassdoor est.)
# $100K-$166K (Glassdoor est.)
# $100K-$173K (Glassdoor est.)
# $100K-$190K (Glassdoor est.)
# $101K-$141K (Glassdoor est.)
# $101K-$158K (Glassdoor est.)
# $102K-$163K (Glassdoor est.)
# $102K-$164K (Glassdoor est.)
# $102K-$165K (Glassdoor est.)
# $102K-$172K (Glassdoor est.)
# $102K-$178K (Glassdoor est.)
# $102K-$190K (Glassdoor est.)
# $105K-$173K (Glassdoor est.)
# $105K-$194K (Glassdoor est.)
# $105K-$198K (Glassdoor est.)
# $106K-$172K (Glassdoor est.)
# $107K-$172K (Glassdoor est.)
# $107K-$173K (Glassdoor est.)
# $108K-$146K (Glassdoor est.)
# $108K-$171K (Glassdoor est.)
# $108K-$173K (Glassdoor est.)
# $108K-$176K (Glassdoor est.)
# $109K-$177K (Glassdoor est.)
# $109K-$200K (Glassdoor est.)
# $110K-$174K (Glassdoor est.)
# $110K-$175K (Glassdoor est.)
# $110K-$184K (Glassdoor est.)
# $111K-$176K (Glassdoor est.)
# $111K-$183K (Glassdoor est.)
# $112K-$179K (Glassdoor est.)
# $112K-$182K (Glassdoor est.)
# $113K-$182K (Glassdoor est.)
# ...

# %% [markdown]
# # companies which are having above 4.0 rating

# %%
df[df.Rating >= 4.0][['Company Name','Rating']]
# Out:
#                 Company Name  Rating
# 2               KnowBe4\n4.8     4.8
# 6    ClearOne Advantage\n4.1     4.1
# 9              <intent>\n4.6     4.6
# 11              ManTech\n4.1     4.1
# 13               Yesler\n4.1     4.1
# ..                       ...     ...
# 716             23andMe\n4.0     4.0
# 718    Moser Consulting\n4.5     4.5
# 727               HOVER\n4.8     4.8
# 732    CK-12 Foundation\n4.1     4.1
# 738          Eventbrite\n4.4     4.4
#
# [219 rows x 2 columns]

# %% [markdown]
# # top 20 locations which are having more no of companies

# %%
df.Location.value_counts().head(20)
# Out:
# New York, NY               55
# San Francisco, CA          49
# Cambridge, MA              47
# Chicago, IL                32
# Boston, MA                 23
# San Jose, CA               13
# Pittsburgh, PA             12
# Washington, DC             11
# Rockville, MD              11
# Winston-Salem, NC          10
# Richland, WA               10
# Herndon, VA                10
# Indianapolis, IN            9
# San Diego, CA               9
# Mountain View, CA           8
# Austin, TX                  8
# South San Francisco, CA     8
# Rochester, NY               7
# Palo Alto, CA               7
# Salt Lake City, UT          6
# Name: Location, dtype: int64

# %% [markdown]
# # fetch only NY loction jobs

# %%
df.groupby('Location').get_group('New York, NY')
# Out:
#                                              Job Title  \
# 4                                       Data Scientist
# 9                                       Data Scientist
# 61                                      Data Scientist
# 100                                     Data Scientist
# 112                                     Data Scientist
# 135                         Data Scientist/ML Engineer
# 179                              Sr. Data Scientist II
# 209                         Business Data Analyst, SQL
# 233                  Data & Analytics Consultant (NYC)
# 272                              Sr. Data Scientist II
# 277                                     Data Scientist
# 340                                      Data Engineer
# 349               Senior Data Scientist - R&D Oncology
# 375       Senior Manager, Epidemiologic Data Scientist
# 378         Marketing Data Analyst, May 2020 Undergrad
# 380                                Senior Data Analyst
# ...

# %% [markdown]
# # fetch Data Scientist jobs for NY loction

# %%
df.groupby(['Job Title','Location']).get_group(('Data Scientist','New York, NY'))
# Out:
#           Job Title               Salary Estimate  \
# 4    Data Scientist   $86K-$143K (Glassdoor est.)
# 9    Data Scientist  $120K-$160K (Glassdoor est.)
# 61   Data Scientist   $84K-$146K (Glassdoor est.)
# 100  Data Scientist   $89K-$153K (Glassdoor est.)
# 112  Data Scientist  $120K-$160K (Glassdoor est.)
# 277  Data Scientist   $95K-$161K (Glassdoor est.)
# 437  Data Scientist   $94K-$162K (Glassdoor est.)
# 455  Data Scientist   $61K-$100K (Glassdoor est.)
# 456  Data Scientist   $81K-$140K (Glassdoor est.)
# 459  Data Scientist  $112K-$179K (Glassdoor est.)
# 460  Data Scientist   $63K-$111K (Glassdoor est.)
# 483  Data Scientist    $56K-$95K (Glassdoor est.)
# 502  Data Scientist   $71K-$124K (Glassdoor est.)
# 505  Data Scientist   $69K-$121K (Glassdoor est.)
# 508  Data Scientist   $77K-$132K (Glassdoor est.)
# 574  Data Scientist   $84K-$146K (Glassdoor est.)
# 657  Data Scientist    $56K-$95K (Glassdoor est.)
# 677  Data Scientist   $69K-$121K (Glassdoor est.)
# ...

# %% [markdown]
# # How many total no of Headquarters are available?

# %%
df.Headquarters.nunique()
# Out:
# 198

# %% [markdown]
# # At which place more no of Headquarters available?

# %%
df.Headquarters.value_counts().head(1)
# Out:
# New York, NY    52
# Name: Headquarters, dtype: int64

# %% [markdown]
# # Fetch top 20 Companies and thier location which have highest no of employees?

# %%
p=df.Size.unique()
p.sort()
print(p)
# Out:
# ['10000+ ' '1001 - 5000 ' '201 - 500 ' '5001 - 10000 ' '501 - 1000 '
#  '51 - 200 ' 'Jan-50' 'unknown']

# %%
df.groupby('Size').get_group('10000+ ')[['Company Name','Location']].head(20)
# Out:
#                                      Company Name         Location
# 1      University of Maryland Medical System\n3.4    Linthicum, MD
# 8                  Rochester Regional Health\n3.3    Rochester, NY
# 12                                   Walmart\n3.2        Plano, TX
# 14                    Takeda Pharmaceuticals\n3.7    Cambridge, MA
# 25                                    Pfizer\n4.0    Cambridge, MA
# 28                                    Pfizer\n4.0       Groton, CT
# 32                                  Novartis\n3.8    Cambridge, MA
# 46                                 Visa Inc.\n3.7     Bellevue, WA
# 49                               Caterpillar\n3.7       Peoria, IL
# 51                  Liberty Mutual Insurance\n3.3       Boston, MA
# 53                                  Swiss Re\n3.7       Armonk, NY
# 54                          Northrop Grumman\n3.7    San Diego, CA
# 64         DICK'S Sporting Goods - Corporate\n3.8   Coraopolis, PA
# ...

# %% [markdown]
# # Newly launched top 20 companies

# %%
df.Founded.unique()
# Out:
# array([1973, 1984, 2010, 1965, 1998, 2000, 2008, 2005, 2014, 2009, 2011,
#        1968, 1962, 2012, 1781, 1995, 1915, 2013, 1935, 1849, 1952, 1852,
#        1997, 1996, 1974, 1969, 1870, 1985,   -1, 2015, 1993, 1958, 1986,
#        1999, 1925, 1912, 2002, 1863, 1939, 2016, 1885, 2006, 1948, 2003,
#        1927, 1978, 1860, 2017, 1942, 1990, 1988, 2001, 2007, 1992, 1994,
#        1977, 2019, 1982, 1937, 1878, 1966, 1971, 1943, 1987, 1945, 1846,
#        1851, 1976, 1981, 1970, 1951, 1967, 1961, 1964, 1930, 1917, 1883,
#        1887, 2004, 1850, 1902, 1744, 1929, 1947, 1991, 1989, 1928, 1875,
#        1913, 1972, 1856, 1983, 1922, 1812, 1914, 1980, 1954, 1830, 1975,
#        1899, 1979, 1889], dtype=int64)

# %%
df.sort_values('Founded').tail(20)
# Out:
#                                              Job Title  \
# 367               Associate Scientist, LC/MS Biologics
# 423                                     Data Scientist
# 57                                      Data Scientist
# 455                                     Data Scientist
# 80                                      Data Scientist
# 430                                     Data Scientist
# 266  Principal Data Scientist with over 10 years ex...
# 450                              Senior Data Scientist
# 553       Principal, Data Science - Advanced Analytics
# 736       Principal, Data Science - Advanced Analytics
# 246                              Medical Lab Scientist
# 320                              Senior Data Scientist
# 78                                      Data Scientist
# 138                                      Data Engineer
# 165                              Medical Lab Scientist
# 176  Principal Data Scientist with over 10 years ex...
# ...

# %% [markdown]
# # Which type of ownership have of all companies

# %%
df['Type of ownership'].unique()
# Out:
# array(['Company - Private', 'Other Organization', 'Government',
#        'Company - Public', 'Hospital', 'Subsidiary or Business Segment',
#        'Nonprofit Organization', 'College / University',
#        'School / School District'], dtype=object)

# %% [markdown]
# # Fetch data for government companies

# %%
df.groupby('Type of ownership').get_group('Government')
# Out:
#                                              Job Title  \
# 3                                       Data Scientist
# 30                                      Data Scientist
# 63   Data Scientist in Artificial Intelligence Earl...
# 144                    Data Scientist - Bioinformatics
# 149                   Senior Data Scientist Statistics
# 166              Risk and Analytics IT, Data Scientist
# 210  Medical Technologist / Clinical Laboratory Sci...
# 242              Risk and Analytics IT, Data Scientist
# 308               Computational Chemist/Data Scientist
# 401      Senior Data Scientist Artificial Intelligence
# 407    Senior Data Scientist 4 Artificial Intelligence
# 426               Computational Chemist/Data Scientist
# 605      Senior Data Scientist Artificial Intelligence
# 614    Senior Data Scientist 4 Artificial Intelligence
# 651  Data Scientist in Artificial Intelligence Earl...
#
#                       Salary Estimate  \
# 3          $56K-$97K (Glassdoor est.)
# ...

# %% [markdown]
# # How many industry type available

# %%
df.Industry.unique()
# Out:
# array(['Aerospace & Defense', 'Health Care Services & Hospitals',
#        'Security Services', 'Energy', 'Advertising & Marketing',
#        'Real Estate', 'Banks & Credit Unions', 'Consulting', 'Internet',
#        'Other Retail Stores', 'Research & Development',
#        'Department, Clothing, & Shoe Stores', 'Biotech & Pharmaceuticals',
#        'Motion Picture Production & Distribution',
#        'Enterprise Software & Network Solutions', 'Insurance Carriers',
#        'Insurance Agencies & Brokerages', 'Logistics & Supply Chain',
#        'Telecommunications Services', 'IT Services',
#        'Computer Hardware & Software', '-1',
#        'Consumer Products Manufacturing', 'Industrial Manufacturing',
#        'Metals Brokers', 'Financial Transaction Processing',
#        'Sporting Goods Stores', 'Staffing & Outsourcing', 'Wholesale',
#        'Mining', 'Financial Analytics & Research', 'Federal Agencies',
#        'Education Training Services',
# ...

# %% [markdown]
# # I want industrial manufacturing companies

# %%
df.groupby('Industry').get_group('Industrial Manufacturing')
# Out:
#                                              Job Title  \
# 49   College Hire - Data Scientist - Open to Decemb...
# 126                                     Data Scientist
# 269                            Data Engineer I - Azure
# 398  College Hire - Data Scientist - Open to Decemb...
#
#                  Salary Estimate  \
# 49    $63K-$99K (Glassdoor est.)
# 126  $82K-$133K (Glassdoor est.)
# 269  $54K-$101K (Glassdoor est.)
# 398   $63K-$99K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 49   Description\n\nCaterpillar's legacy of industr...     3.7
# 126  For more than 50 years, Accuride International...     3.6
# 269  You’re not likely to find another company like...     3.9
# 398  Description\n\nCaterpillar's legacy of industr...     3.7
#
#                     Company Name                           Location  \
# 49              Caterpillar\n3.7                         Peoria, IL
# ...

# %% [markdown]
# # Show unique sectors of all companies

# %%
df.Sector.unique()
# Out:
# array(['Aerospace & Defense', 'Health Care', 'Business Services',
#        'Oil, Gas, Energy & Utilities', 'Real Estate', 'Finance',
#        'Information Technology', 'Retail', 'Biotech & Pharmaceuticals',
#        'Media', 'Insurance', 'Transportation & Logistics',
#        'Telecommunications', '-1', 'Manufacturing', 'Mining & Metals',
#        'Government', 'Education', 'Agriculture & Forestry',
#        'Travel & Tourism', 'Non-Profit',
#        'Arts, Entertainment & Recreation',
#        'Construction, Repair & Maintenance', 'Accounting & Legal',
#        'Consumer Services'], dtype=object)

# %% [markdown]
# # Top 10 companies which completed more no of years

# %%
df.loc[:].sort_values('Age',ascending=False).head(10)
# Out:
#                                              Job Title  \
# 277                                     Data Scientist
# 342  Associate Director, Platform and DevOps- Data ...
# 676  Associate Director, Platform and DevOps- Data ...
# 174                 Principal Scientist - Immunologist
# 270  Sr. Scientist, Quantitative Translational Scie...
# 14                                      Data Scientist
# 178  Sr. Scientist, Quantitative Translational Scie...
# 261                 Principal Scientist - Immunologist
# 259  Sr. Scientist - Digital & Image Analysis/Compu...
# 172  Sr. Scientist - Digital & Image Analysis/Compu...
#
#                   Salary Estimate  \
# 277   $95K-$161K (Glassdoor est.)
# 342  $113K-$196K (Glassdoor est.)
# 676  $113K-$196K (Glassdoor est.)
# 174   $98K-$182K (Glassdoor est.)
# 270  $117K-$206K (Glassdoor est.)
# 14    $83K-$144K (Glassdoor est.)
# 178  $117K-$206K (Glassdoor est.)
# 261   $98K-$182K (Glassdoor est.)
# 259  $105K-$198K (Glassdoor est.)
# ...
