# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
c=pd.read_csv('tested.csv')
c.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
c.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
c.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
c.shape
# Out:
# (418, 12)

# %%
c.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#display %wise Male vs Female distribution
gender= c.Sex.value_counts()
gender
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
gender.index
# Out:
# Index(['male', 'female'], dtype='object', name='Sex')

# %%
gender.values
# Out:
# array([266, 152])

# %%
plt.pie(gender.values,labels=gender.index,autopct='%2f%%')
plt.show()

# %%
#countplot
sns.countplot(x='Sex', data=c)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
c
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#claswise count
sns.countplot(x='Pclass',  data=c)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Pclass', data=c,hue='Sex',palette='rainbow')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Pclass', data=c,hue='Sex',palette='PuBu')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#same as above if we want scatter plot plot instead bar plot

sns.stripplot(x='Pclass',y='Age',data=c)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.stripplot(x='Sex', y='Age', data=c)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#w.r/t survival Lets check new things
sns.countplot(x='Survived',data=c)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',data=c, hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', data=c,hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# #Pairplot

# %%
sns.pairplot(c)

# %%
c.select_dtypes(exclude='object')
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3   NaN      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3   NaN      0      0    8.0500
# 417         1309         0       3   NaN      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
sns.pairplot(c[['Pclass','Age','Fare']])

# %%
#iris flower
ir=sns.load_dataset('iris')
sns.pairplot(ir)

# %%
ir=sns.load_dataset('iris')
sns.pairplot(ir, hue='species')

# %%
sns.histplot(x='Age',data=c, hue='Pclass')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Age',data=c, hue='Pclass',bins=[23,35,55,70])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# sns.lineplot
# sns.barplot
# sns.boxplot
# sns.kdelpot

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_base', '_compat', '_core', '_docstrings', '_orig_rc_params', '_statistics', '_stats', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'displot', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'ecdfplot', 'external', 'get_data_home', 'get_dataset_names', 'heatmap', 'histplot', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'matrix', 'miscplot', 'move_legend', 'mpl', 'mpl_palette', 'pairplot'
# ...

# %%
# Explor: Plotly, Cufflink,ggplot(R Lang)

# %%
import plotly.express as px

x = ['Category 1', 'Category 2', 'Category 3']
y = [5, 3, 6]

fig = px.bar(x, y)
fig.show()
